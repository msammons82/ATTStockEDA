# 2010-10-20  19.722521
# 2010-10-21  19.725281
# 2010-10-22  19.729023
# ...               ...
# 2022-04-04  19.490710
# 2022-04-05  19.471683
# 2022-04-06  19.453751
# 2022-04-07  19.435177
# 2022-04-08  19.417623
#
# [2890 rows x 7 columns]

# %%
plt.figure(figsize = (20,12))
plt.plot(df['Volume'])

# %%
df.plot(figsize = (18,6))

# %%
df[['Open', 'Close', 'High', 'Low']].plot(figsize = (20,12))
plt.title('ATT Stock at all time')
# Out:
# Text(0.5, 1.0, 'ATT Stock at all time')

# %%
df[['Open', 'Close']].plot(figsize=(20,10))
plt.title('Att stock price action')
plt.xlabel('Date')
plt.ylabel('Stock Action')
# Out:
# Text(0, 0.5, 'Stock Action')

# %%
df[['Open', 'High']].plot(figsize=(20,10))
plt.title('ATT Stock price action')
plt.xlabel('Date')
plt.ylabel('Stock Action')
# Out:
# Text(0, 0.5, 'Stock Action')

# %%
df['Volume'].plot(figsize = (20,10))
plt.title('ATT stock Volume')
plt.xlabel('Date')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
print(adf_test(df['High']))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -1.967322
# p-value                           0.301082
# #Lags Used                        7.000000
# Number of Observations Used    3081.000000
# Critical Value (1%)              -3.432474
# Critical Value (5%)              -2.862479
# Critical Value (10%)             -2.567270
# dtype: float64
# None

# %%
print(adf_test(df['High'].resample('MS').mean()))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.089708
# p-value                          0.248673
# #Lags Used                       1.000000
# Number of Observations Used    146.000000
# Critical Value (1%)             -3.475953
# Critical Value (5%)             -2.881548
# Critical Value (10%)            -2.577439
# dtype: float64
# None

# %%
att_diff = df['Open'].resample('MS').mean() - df['Open'].resample('MS').mean().shift(1)
att_open_diff = att_diff.dropna()
att_open_diff.plot()

print(adf_test(att_open_diff))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -9.822717e+00
# p-value                        5.285670e-17
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.460000e+02
# Critical Value (1%)           -3.475953e+00
# Critical Value (5%)           -2.881548e+00
# Critical Value (10%)          -2.577439e+00
# dtype: float64
# None

# %% [markdown]
# # KPSS

# %%
from statsmodels.tsa.stattools import kpss

# %%
def kpss_test(timeseries):
    print("Results of KPSS Test:")
    kpsstest = kpss(timeseries, regression="c", lags="auto")
    kpss_output = pd.Series(
        kpsstest[0:3], index=["Test Statistic", "p-value", "Lags Used"]
    )
    for key, value in kpsstest[3].items():
        kpss_output["Critical Value (%s)" % key] = value
    print(kpss_output)

# %%
kpss_test(df['High'])
# Out:
# Results of KPSS Test:
# Test Statistic            1.567994
# p-value                   0.010000
# Lags Used                32.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1709: InterpolationWarning: p-value is smaller than the indicated p-value
#   warn("p-value is smaller than the indicated p-value", InterpolationWarning)

# %%
df['High_diff'] = df['High'] - df['High'].shift(1)
df['High_diff'].dropna().plot(figsize = (12,8))

# %%
kpss_test(df['High_diff'].dropna())
# Out:
# Results of KPSS Test:
# Test Statistic            0.168965
# p-value                   0.100000
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1711: InterpolationWarning: p-value is greater than the indicated p-value
#   warn("p-value is greater than the indicated p-value", InterpolationWarning)

# %%
kpss_test(df['High_diff'].resample('MS').mean().dropna())
# Out:
# Results of KPSS Test:
# Test Statistic           0.172333
# p-value                  0.100000
# Lags Used                2.000000
# Critical Value (10%)     0.347000
# Critical Value (5%)      0.463000
# Critical Value (2.5%)    0.574000
# Critical Value (1%)      0.739000
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1711: InterpolationWarning: p-value is greater than the indicated p-value
#   warn("p-value is greater than the indicated p-value", InterpolationWarning)

# %%
kpss_test(df['High_diff'].resample('MS').std().dropna())
# Out:
# Results of KPSS Test:
# Test Statistic           1.256984
# p-value                  0.010000
# Lags Used                5.000000
# Critical Value (10%)     0.347000
# Critical Value (5%)      0.463000
# Critical Value (2.5%)    0.574000
# Critical Value (1%)      0.739000
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1709: InterpolationWarning: p-value is smaller than the indicated p-value
#   warn("p-value is smaller than the indicated p-value", InterpolationWarning)

# %%
adf_test(df['High_diff'].dropna())
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -21.353908
# p-value                           0.000000
# #Lags Used                        6.000000
# Number of Observations Used    3081.000000
# Critical Value (1%)              -3.432474
# Critical Value (5%)              -2.862479
# Critical Value (10%)             -2.567270
# dtype: float64

# %% [markdown]
# # Data Preprocessing

# %%
train_df = df['High'].iloc[:-4]

X_train = []
y_train = []

for i in range(2, len(train_df)):
  X_train.append(train_df[i-2:i])
  y_train.append(train_df[i])

# %%
import math
train_len = math.ceil(len(train_df)*0.8)
train_len
# Out:
# 2468

# %% [markdown]
# # For Model and apply RNN + LSTM

# %%
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Activation, Dropout, TimeDistributed
from tensorflow.keras.models import Sequential

# %%
X_train, y_train= np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
model=Sequential()
model.add(LSTM(50,activation='relu', input_shape=(X_train.shape[1],1)))
model.add(Dense(25))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
model.fit(X_train, y_train, epochs=10, batch_size=100, verbose=2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                10400
#
#  dense (Dense)               (None, 25)                1275
#
#  dense_1 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 11,701
# Trainable params: 11,701
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 31/31 - 3s - loss: 285.6595 - 3s/epoch - 100ms/step
# Epoch 2/10
# 31/31 - 0s - loss: 6.4543 - 132ms/epoch - 4ms/step
# Epoch 3/10
# 31/31 - 0s - loss: 0.9949 - 115ms/epoch - 4ms/step
# Epoch 4/10
# 31/31 - 0s - loss: 0.4903 - 129ms/epoch - 4ms/step
# Epoch 5/10
# 31/31 - 0s - loss: 0.4273 - 120ms/epoch - 4ms/step
# Epoch 6/10
# 31/31 - 0s - loss: 0.3792 - 111ms/epoch - 4ms/step
# Epoch 7/10
# 31/31 - 0s - loss: 0.3323 - 113ms/epoch - 4ms/step
# Epoch 8/10
# 31/31 - 0s - loss: 0.2895 - 143ms/epoch - 5ms/step
# Epoch 9/10
# 31/31 - 0s - loss: 0.2481 - 124ms/epoch - 4ms/step
# Epoch 10/10
# 31/31 - 0s - loss: 0.2016 - 119ms/epoch - 4ms/step

# %%
losse = pd.DataFrame(model.history.history)
losse[['loss']].plot()

# %%
test_data = train_df[train_len-2:]
X_val=[]
Y_val=[] 

for i in range(2, len(test_data)):
    X_val.append(test_data[i-2:i])
    Y_val.append(test_data[i])

# %%
X_val, Y_val = np.array(X_val), np.array(Y_val)
X_val = np.reshape(X_val, (X_val.shape[0], X_val.shape[1],1))
prediction = model.predict(X_val)

# %%
from sklearn.metrics import mean_squared_error
# Know the model error accuracy | the model accuracy 
lstm_train_pred = model.predict(X_train)
lstm_valid_pred = model.predict(X_val)
print('Train rmse:', np.sqrt(mean_squared_error(y_train, lstm_train_pred)))
print('Validation rmse:', np.sqrt(mean_squared_error(Y_val, lstm_valid_pred)))
# Out:
# Train rmse: 0.41352144571747385
# Validation rmse: 0.5435007552063675

# %%
valid = pd.DataFrame(train_df[train_len:])
valid['Predictions']=lstm_valid_pred 
plt.figure(figsize=(16,8))
plt.plot(valid[['High','Predictions']])
plt.legend(['Validation','Predictions'])
plt.show()

# %%
variance = []
for i in range(len(valid)):
  
  variance.append(valid['High'][i]-valid['Predictions'][i])
variance = pd.DataFrame(variance)
variance.describe()
# Out:
#                 0
# count  617.000000
# mean     0.164893
# std      0.518304
# min     -3.010704
# 25%     -0.076017
# 50%      0.193687
# 75%      0.435696
# max      1.802109

# %%
train = train_df[:train_len]
valid = pd.DataFrame(train_df[train_len:])
valid['Predictions']=lstm_valid_pred

plt.figure(figsize=(16,8))
plt.title('Model LSTM')
plt.xlabel('Date')
plt.ylabel('ATT Price USD')
plt.plot(train)
plt.plot(valid[['High','Predictions']])
plt.legend(['Train','Val','Predictions'])
plt.show()
